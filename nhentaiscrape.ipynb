# %%
import dnscrape

# %%
manga_id = "190547"
site = "nhentai"
if(site == "nhentai"):
    dnscrape.nhentai(manga_id)
elif(site == "erolord"):
    dnscrape.erolord(manga_id)
# Out:
# 1.jpg downloaded
# 2.jpg downloaded
# 3.jpg downloaded
# 4.jpg downloaded
# 5.jpg downloaded
# 6.jpg downloaded
# 7.jpg downloaded
# 8.jpg downloaded
# 9.jpg downloaded
# 10.jpg downloaded
# 11.jpg downloaded
# 12.jpg downloaded
# 13.jpg downloaded
# 14.jpg downloaded
# 15.jpg downloaded
# 16.jpg downloaded
# 17.jpg downloaded
# 18.jpg downloaded
# 19.jpg downloaded
# 20.jpg downloaded
# 21.jpg downloaded
# 22.jpg downloaded
# 23.jpg downloaded
# 24.jpg downloaded
# 25.jpg downloaded
# 26.jpg downloaded
# 27.jpg downloaded
# 28.jpg downloaded
# 29.jpg downloaded
# 30.jpg downloaded
# 31.jpg downloaded
# 32.jpg downloaded
# 33.jpg downloaded
# 34.jpg downloaded
# 35.jpg downloaded
# 36.jpg downloaded
# 37.jpg downloaded
# 38.jpg downloaded
# 39.jpg downloaded
# 40.jpg downloaded
# 41.jpg downloaded
# 42.jpg downloaded
# 43.jpg downloaded
# 44.jpg downloaded
# 45.jpg downloaded
# 46.jpg downloaded
# 47.jpg downloaded
# 48.jpg downloaded
# 49.jpg downloaded
# 50.jpg downloaded
# ...
